# %%
# Import des bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Configuration
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Bibliothèques chargées avec succès !")
# Out:
# ✅ Bibliothèques chargées avec succès !

# %%
# Charger les données préparées au Jour 2
DATA_PATH = "../data/processed/"

transactions_enrichies = pd.read_csv(DATA_PATH + "transactions_enrichies.csv")

# %%
# Courbe de distribution du CA par client avec seaborn
ca_par_client = transactions_enrichies.groupby('client_id')['price'].sum().reset_index()
ca_par_client

# Courbe de distribution du CA par client avec seaborn
ca_par_client_b2c = transactions_enrichies[transactions_enrichies['segment_client'] == 'B2C'].groupby('client_id')['price'].sum().reset_index()
ca_par_client_b2b = transactions_enrichies[transactions_enrichies['segment_client'] == 'B2B'].groupby('client_id')['price'].sum().reset_index()

# %%
# Courbe de distribution du CA par client avec seaborn
sns.histplot(ca_par_client_b2c['price'], kde=True)
plt.title("Distribution du CA par client")
# Out:
# Text(0.5, 1.0, 'Distribution du CA par client')
